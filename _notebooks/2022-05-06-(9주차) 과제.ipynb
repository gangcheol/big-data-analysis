# %% [markdown]
# # (9주차) 과제
#
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 최규빈
# - editor : 이강철
# - published : true

# %% [markdown]
# ## Import

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow.experimental.numpy as tnp

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
y= y_train[(y_train==0) | (y_train==1)].reshape(-1,1)
X= x_train[(y_train==0) | (y_train==1)].reshape(-1,784)
yy= y_test[(y_test==0) | (y_test==1)].reshape(-1,1) 
XX= x_test[(y_test==0) | (y_test==1)].reshape(-1,784)

# %%
tf.random.set_seed(43052)
net = tf.keras.Sequential()
net.add(tf.keras.layers.Dense(30,activation='relu'))
net.add(tf.keras.layers.Dense(1,activation='sigmoid'))
net.compile(optimizer='adam',loss=tf.losses.binary_crossentropy,metrics=['accuracy']) 
net.fit(X,y,epochs=10,batch_size=240)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 3ms/step - loss: 10.8457 - accuracy: 0.9076
# Epoch 2/10
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6439 - accuracy: 0.9776
# Epoch 3/10
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5190 - accuracy: 0.9793
# Epoch 4/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.9820
# Epoch 5/10
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3632 - accuracy: 0.9803
# Epoch 6/10
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2937 - accuracy: 0.9846
# Epoch 7/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2497 - accuracy: 0.9864
# Epoch 8/10
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2256 - accuracy: 0.9866
# Epoch 9/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.9875
# Epoch 10/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1778 - accuracy: 0.9888
